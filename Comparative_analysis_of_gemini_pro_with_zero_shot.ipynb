# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshi07-c/Enhancing-LLM-s-Response-for-Lesson-preparation-Material-by-Prompt-Refinement-Technique/blob/main/Comparative_analysis_of_gemini_pro_with_zero_shot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/lecture_rankings (1).csv")

# %%
df
# Out:
#                                                 query 1st 2nd 3rd
# 0   Compare and contrast different sorting techniq...  TB  FS  ZS
# 1   Illustrate the concept of doubly linked lists ...  FS  ZS  TB
# 2   Explain the implementation of stacks using lin...  TB  FS  ZS
# 3   Discuss the applications of arrays in data str...  TB  ZS  FS
# 4   Illustrate the concept of strings in the conte...  TB  ZS  FS
# 5   Explain how linked lists are utilized in repre...  TB  ZS  FS
# 6   Discuss the role of the Dutch National Flag al...  FS  ZS  TB
# 7   Explain how stacks can be implemented iterativ...  TB  ZS  FS
# 8   Illustrate the usage of queues in the context ...  TB  ZS  FS
# 9   Explain the process of hashing and its signifi...  ZS  TB  FS
# 10  Discuss the structure and operations of trees,...  TB  FS  ZS
# 11  Discuss the concept of search algorithms, incl...  TB  FS  ZS
# 12  Illustrate the working principles of sorting a...  ZS  TB  FS
# ...

# %%
# Count occurrences of FS, TB, and ZS at rank 1
rank_1_counts = df['1st'].value_counts()

# Plot the counts
plt.figure(figsize=(8, 6))
rank_1_counts.plot(kind='bar', color=['blue', 'green', 'red'])
plt.title('Occurrences of FS, TB, and ZS at Rank 1')
plt.xlabel('Technique')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='')  # Set linestyle to an empty string
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get the counts for each rank and technique
counts = {
    'Rank 1': df['1st'].value_counts(),
    'Rank 2': df['2nd'].value_counts(),
    'Rank 3': df['3rd'].value_counts()
}

# Define the techniques
techniques = ['FS', 'TB', 'ZS']

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.2

# Set the x locations for the groups
index = np.arange(len(counts))

# Plot each technique
for i, (rank, count) in enumerate(counts.items()):
    ax.bar(index + i * bar_width, count.reindex(techniques, fill_value=0), bar_width, label=rank)

# Customize the plot
ax.set_title('Counts of FS, TB, and ZS Across Ranks')
ax.set_xlabel('Rank')
ax.set_ylabel('Count')
ax.set_xticks(index + bar_width)
ax.set_xticklabels(techniques)
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## QUERY TYPE WISE

# %% [markdown]
# ###Comparison Query

# %%
comparison_queries = [
    "Compare and contrast different sorting techniques such as bubble sort, selection sort, and insertion sort, highlighting their time and space complexities.",
    "Illustrate the concept of doubly linked lists and their advantages over singly linked lists."
]

# Filter the DataFrame for the comparison queries
filtered_df = df[df['query'].isin(comparison_queries)]

# Display the filtered DataFrame
filtered_df
# Out:
#                                                query 1st 2nd 3rd
# 0  Compare and contrast different sorting techniq...  TB  FS  ZS
# 1  Illustrate the concept of doubly linked lists ...  FS  ZS  TB
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# filtered_df.groupby('query').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# filtered_df.groupby('1st').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# filtered_df.groupby('2nd').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
# Define the comparison queries
comparison_queries = [
    "Compare and contrast different sorting techniques such as bubble sort, selection sort, and insertion sort, highlighting their time and space complexities.",
    "Illustrate the concept of doubly linked lists and their advantages over singly linked lists."
]


# Filter the DataFrame to include only the comparison queries
comparison_df = df[df['query'].isin(comparison_queries)]

# Create a DataFrame to store the count of TB in each rank for comparison queries
tb_comparison_count_df = pd.DataFrame(columns=['Rank', 'Count'])

# Iterate over each rank
for rank in ['1st', '2nd', '3rd']:
    # Count the occurrences of TB in the specified rank for comparison queries
    tb_comparison_count = comparison_df[rank].value_counts().get('TB', 0)
    # Append the count to the DataFrame
    tb_comparison_count_df = tb_comparison_count_df.append({'Rank': rank, 'Count': tb_comparison_count}, ignore_index=True)

# Plot the count of TB in each rank for comparison queries
plt.figure(figsize=(8, 6))
sns.barplot(data=tb_comparison_count_df, x='Rank', y='Count', palette='viridis')
plt.title('Count of TB in Each Rank for Comparison Queries')
plt.xlabel('Rank')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-4e52421edcbe>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tb_comparison_count_df = tb_comparison_count_df.append({'Rank': rank, 'Count': tb_comparison_count}, ignore_index=True)
# <ipython-input-32-4e52421edcbe>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tb_comparison_count_df = tb_comparison_count_df.append({'Rank': rank, 'Count': tb_comparison_count}, ignore_index=True)
# <ipython-input-32-4e52421edcbe>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tb_comparison_count_df = tb_comparison_count_df.append({'Rank': rank, 'Count': tb_comparison_count}, ignore_index=True)
# <ipython-input-32-4e52421edcbe>:23: FutureWarning:
#
# ...

# %% [markdown]
# ###Topic Combo

# %%
topics_combo = [
    "Explain the implementation of stacks using linked lists.",
    "Discuss the applications of arrays in data structures and algorithms.",
    "Illustrate the concept of strings in the context of pattern searching.",
    "Explain how linked lists are utilized in representing polynomial expressions.",
    "Discuss the role of the Dutch National Flag algorithm in sorting algorithms.",
    "Explain how stacks can be implemented iteratively, focusing on the iterative process.",
    "Illustrate the usage of queues in the context of breadth-first search.",
    "Explain the process of hashing and its significance in data storage and retrieval.",
    "Discuss the structure and operations of trees, emphasizing binary trees.",
    "Discuss the concept of search algorithms, including linear and binary search.",
    "Illustrate the working principles of sorting algorithms such as bubble sort and selection sort.",
    "Explain the divide and conquer approach in algorithm design, with examples like merge sort.",
    "Discuss the greedy algorithm paradigm and its applications in optimization problems."
]
data = []
# Iterate over each rank
for rank in ['1st', '2nd', '3rd']:
    # Count the occurrences of TB in the specified rank for the filtered topics
    tb_count = filtered_df[rank].value_counts().get('TB', 0)
    # Append the data to the list
    data.append({'Rank': rank, 'Count': tb_count})

# Create a DataFrame from the list of dictionaries
tb_count_df = pd.DataFrame(data)

# Plot the count of TB in each rank for the filtered topics
plt.figure(figsize=(8, 6))
sns.barplot(data=tb_count_df, x='Rank', y='Count', palette='viridis')
plt.title('Count of TB in Each Rank for Topics Combination.')
plt.xlabel('Rank')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-3a586404fcdc>:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tb_count_df, x='Rank', y='Count', palette='viridis')

# %%
# Initialize counters for TB counts in each rank
tb_count_1st = filtered_df['1st'].value_counts().get('TB', 0)
tb_count_2nd = filtered_df['2nd'].value_counts().get('TB', 0)
tb_count_3rd = filtered_df['3rd'].value_counts().get('TB', 0)

print("TB count for 1st rank:", tb_count_1st)
print("TB count for 2nd rank:", tb_count_2nd)
print("TB count for 3rd rank:", tb_count_3rd)
# Out:
# TB count for 1st rank: 9
# TB count for 2nd rank: 2
# TB count for 3rd rank: 2

# %% [markdown]
# ###Single Topic

# %%
single_topic = [
    "Provide lecture prepration material on Data Structure And Algorithm Intro",
    "Share instructional resources for the lecture Array",
    "Provide lecture prepration material on String",
    "Share instructional resources for the lecture Linked Lists",
    "Provide lecture prepration material on dutch national flag algorithm",
    "Provide instructional content for the upcoming lecture on stack using iterative process",
    "Share instructional resources for the lecture queue",
    "Provide lecture prepration material on heap",
    "Share instructional resources for the lecture hashing",
    "Provide lecture prepration material on tree",
    "Provide instructional content for the upcoming lecture on graph",
    "Provide lecture prepration material on search algorithms",
    "Provide lecture prepration material on sorting algorithm",
    "Share instructional resources for the lecture divide and conquer",
    "Provide lecture prepration material on greedy algorithm",
    "Provide lecture prepration material on recursion",
    "Provide lecture prepration material on backtracking",
    "Share instructional resources for the lecture dynamic programming",
    "Provide lecture prepration material on priority queue",
    "Share instructional resources for the lecture Bitwise Algorithms",
    "Provide lecture prepration material on Branch and Bound Algorithm",
    "Provide lecture prepration material on multidimensional array",
    "Provide lecture prepration material on kadane's algorithm",
    "Share instructional resources for the lecture on  max-heap",
    "Provide lecture prepration material on min-heap"
]

# %%
# Filter the DataFrame to include only the single topic queries
ST_df = df[df['query'].isin(single_topic)]

# Initialize an empty list to store the data
data = []

# Iterate over each rank
for rank in ['1st', '2nd', '3rd']:
    # Count the occurrences of TB in the specified rank for single topic queries
    tb_count = ST_df[rank].value_counts().get('TB', 0)
    # Append the data to the list
    data.append({'Rank': rank, 'Count': tb_count})

# Create a DataFrame from the list of dictionaries
tb_ST_count_df = pd.DataFrame(data)

# Plot the count of TB in each rank for single topic queries
plt.figure(figsize=(8, 6))
sns.barplot(data=tb_ST_count_df, x='Rank', y='Count', palette='viridis')
plt.title('Count of TB in Each Rank for Single Topic Queries')
plt.xlabel('Rank')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-4da932eee1c1>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tb_ST_count_df, x='Rank', y='Count', palette='viridis')

# %%
# Initialize counters for TB counts in each rank
tb_count_1st = ST_df['1st'].value_counts().get('TB', 0)
tb_count_2nd = ST_df['2nd'].value_counts().get('TB', 0)
tb_count_3rd = ST_df['3rd'].value_counts().get('TB', 0)

print("TB count for 1st rank:", tb_count_1st)
print("TB count for 2nd rank:", tb_count_2nd)
print("TB count for 3rd rank:", tb_count_3rd)
# Out:
# TB count for 1st rank: 21
# TB count for 2nd rank: 2
# TB count for 3rd rank: 2

# %% [markdown]
# ###Programming Problem

# %%
programming_problem = [
    "Share instructional resources for the lecture fractional knapsack problem",
    "Provide lecture prepration material on tower of hanoi",
    "Share instructional resources for the lecture Knight's tour problem",
    "Provide instructional content for the upcoming lecture Rat in a maze",
    "Share instructional resources for the lecture N-Queen problem",
    "Provide lecture prepration material on Subset sum problem",
    "Provide lecture prepration material on m-coloring problem",
    "Provide educational content for the lecture on rotation of array ",
    "Share instructional resources for the lecture on rearranging array"
]

# %%
# Filter the DataFrame to include only the comparison queries
PP_df = df[df['query'].isin(programming_problem)]

# Initialize an empty list to store the data
data = []

# Iterate over each rank
for rank in ['1st', '2nd', '3rd']:
    # Count the occurrences of TB in the specified rank for programming problem queries
    tb_PP_count = PP_df[rank].value_counts().get('TB', 0)
    # Append the data to the list
    data.append({'Rank': rank, 'Count': tb_PP_count})

# Create a DataFrame from the list of dictionaries
tb_PP_count_df = pd.DataFrame(data)

# Plot the count of TB in each rank for programming problem queries
plt.figure(figsize=(8, 6))
sns.barplot(data=tb_PP_count_df, x='Rank', y='Count', palette='viridis')
plt.title('Count of TB in Each Rank for Programming Problem Queries')
plt.xlabel('Rank')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-19b662edbd03>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tb_PP_count_df, x='Rank', y='Count', palette='viridis')

# %%
# Initialize counters for TB counts in each rank
tb_count_1st = PP_df['1st'].value_counts().get('TB', 0)
tb_count_2nd = PP_df['2nd'].value_counts().get('TB', 0)
tb_count_3rd = PP_df['3rd'].value_counts().get('TB', 0)

print("TB count for 1st rank:", tb_count_1st)
print("TB count for 2nd rank:", tb_count_2nd)
print("TB count for 3rd rank:", tb_count_3rd)
# Out:
# TB count for 1st rank: 6
# TB count for 2nd rank: 3
# TB count for 3rd rank: 0

# %% [markdown]
# ###OOPS and Complexity

# %%
df[df['query'] == 'Provide lecture prepration material on time complexity']
# Out:
#                                                 query 1st 2nd 3rd
# 49  Provide lecture prepration material on time co...  TB  ZS  FS
